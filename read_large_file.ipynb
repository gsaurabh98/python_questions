# %%
x = []
with open("/home/winjit/Documents/CHANGELOG") as infile:
#     infile.read()
    for line in infile:
#         do_something_with(line)
        x.append(line)

# %%
import pandas as pd

# %%
df = pd.DataFrame(x)

# %%
df
# Out:
#                                                      0
# 0                                                   \n
# 1                                   Latest Version: \n
# 2                         Robo 3T 1.2 (14 Feb, 2018)\n
# 3              http://blog.robomongo.org/robo-3t-1-2\n
# 4                     https://robomongo.org/download\n
# ..                                                 ...
# 597    * Hotkeys for first 9 connections (Alt+1, .....
# 598    * Connections reordering via drag'n'drop in ...
# 599    * Correct focus placement when opening new c...
# 600    * Bonus: F12 - opens connections menu from a...
# 601                              * Memory leaks fix.\n
#
# [602 rows x 1 columns]

# %%
file = open('/home/winjit/Documents/CHANGELOG', 'r')

# %%
data= file.read().split('\n')

# %%
data
# Out:
# ['',
#  'Latest Version: ',
#  'Robo 3T 1.2 (14 Feb, 2018)',
#  'http://blog.robomongo.org/robo-3t-1-2',
#  'https://robomongo.org/download',
#  '',
#  'Robo 3T 1.x:',
#  '  Major Features: ',
#  '    - MongoDB 3.4 support',
#  '    - Replica set support.',
#  '    - ECMAScript 2015 aka ES6 Support (Modernized JavaScript Implementation)',
#  '    - Update Notifications Bar',
#  '    - Welcome Tab',
#  '    - New operation logging for almost all operations.',
#  '',
#  '  Major Fixes/Improvements:',
#  '    - Fix for Robomongo Shell Timeout Issue (silently, prematurely finishing long lasting scripts) ',
#  '    - New NumberDecimal (Decimal128) data type support',
#  '    - Aggregate query results are pagaeble now',
#  '    - Fix for Big double numbers are showing incorrectly #1447',
#  '    - Fix for Editing a document from a projection causes data loss (override) (#881)',
#  '    - Improved error handling (no double error windows) for almost all operations.',
# ...

# %%
text_data = list(filter(None, data))

# %%
text_data
# Out:
# ['Latest Version: ',
#  'Robo 3T 1.2 (14 Feb, 2018)',
#  'http://blog.robomongo.org/robo-3t-1-2',
#  'https://robomongo.org/download',
#  'Robo 3T 1.x:',
#  '  Major Features: ',
#  '    - MongoDB 3.4 support',
#  '    - Replica set support.',
#  '    - ECMAScript 2015 aka ES6 Support (Modernized JavaScript Implementation)',
#  '    - Update Notifications Bar',
#  '    - Welcome Tab',
#  '    - New operation logging for almost all operations.',
#  '  Major Fixes/Improvements:',
#  '    - Fix for Robomongo Shell Timeout Issue (silently, prematurely finishing long lasting scripts) ',
#  '    - New NumberDecimal (Decimal128) data type support',
#  '    - Aggregate query results are pagaeble now',
#  '    - Fix for Big double numbers are showing incorrectly #1447',
#  '    - Fix for Editing a document from a projection causes data loss (override) (#881)',
#  '    - Improved error handling (no double error windows) for almost all operations.',
# ...

# %%
import numpy as np

# %%
x = pd.read_pickle('/home/winjit/Documents/predictsense/toolkit/1_build_linux/app/models/TK-file_exams-Linear_Regression-5fb4bf062bb48052176d6a7e/trainingFile.pkl')

# %%
pd.read_pickle('/home/winjit/Documents/predictsense/toolkit/1_build_linux/app/models/TK-file_exams-Linear_Regression-5fb4bf062bb48052176d6a7e/split_indexes-1605680902.pkl')

# %%
x['high_gpa'].to_frame()
# Out:
#      high_gpa
# 0        2.79
# 1        2.78
# 2        2.52
# 3        3.67
# 4        3.24
# ..        ...
# 100      3.76
# 101      3.49
# 102      3.07
# 103      2.19
# 104      3.46
#
# [105 rows x 1 columns]
